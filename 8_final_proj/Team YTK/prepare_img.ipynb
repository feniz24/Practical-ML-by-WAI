# %%
import cv2
import os
import matplotlib.pyplot as plt

test_img_path = "./test_dataset/cats_and_dogs_filtered/train/dogs"
os.listdir(test_img_path)
# Out:
# ['dog.775.jpg',
#  'dog.761.jpg',
#  'dog.991.jpg',
#  'dog.2266.jpg',
#  'dog.749.jpg',
#  'dog.985.jpg',
#  'dog.2272.jpg',
#  'dog.2299.jpg',
#  'dog.952.jpg',
#  'dog.946.jpg',
#  'dog.211.jpg',
#  'dog.577.jpg',
#  'dog.2058.jpg',
#  'dog.563.jpg',
#  'dog.205.jpg',
#  'dog.2064.jpg',
#  'dog.2070.jpg',
#  'dog.239.jpg',
#  'dog.588.jpg',
#  'dog.365.jpg',
#  'dog.403.jpg',
#  'dog.2138.jpg',
#  'dog.417.jpg',
#  'dog.371.jpg',
#  'dog.359.jpg',
#  'dog.2110.jpg',
#  'dog.2104.jpg',
#  'dog.601.jpg',
#  'dog.167.jpg',
#  'dog.173.jpg',
#  'dog.615.jpg',
#  'dog.2312.jpg',
#  'dog.36.jpg',
#  'dog.2474.jpg',
#  'dog.22.jpg',
#  'dog.629.jpg',
#  'dog.2306.jpg',
#  'dog.826.jpg',
#  'dog.198.jpg',
#  'dog.832.jpg',
#  'dog.833.jpg',
#  'dog.827.jpg',
#  'dog.199.jpg',
#  'dog.2307.jpg',
#  'dog.628.jpg',
#  'dog.23.jpg',
#  'dog.37.jpg',
#  'dog.2313.jpg',
#  'dog.2475.jpg',
#  'dog.172.jpg',
#  'dog.614.jpg',
#  'dog.600.jpg',
#  'dog.166.jpg',
#  'dog.2105.jpg',
# ...
